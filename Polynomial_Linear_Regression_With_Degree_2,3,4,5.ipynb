# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## DataSet Reperesentation

# %%
df = pd.read_csv("C:\\Users\\PMLS\\Desktop\\Data_Sets\\Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X = df['YearsExperience'].values
y = df['Salary'].values
X,y
# Out:
# (array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#          4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#          7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5]),
#  array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#          54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#          61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#          98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#         122391., 121872.]))

# %%
X = np.reshape(X,(-1,1))
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %% [markdown]
# ## Ploynomial_Linear_Regression With Degree 2,3,4,5¶

# %% [markdown]
# ### Ploynomial_Linear_Regression With Degree 2

# %%
pt = PolynomialFeatures(degree = 2)
X_poly = pt.fit_transform(X)
X , X_poly
# Out:
# (array([[ 1.1],
#         [ 1.3],
#         [ 1.5],
#         [ 2. ],
#         [ 2.2],
#         [ 2.9],
#         [ 3. ],
#         [ 3.2],
#         [ 3.2],
#         [ 3.7],
#         [ 3.9],
#         [ 4. ],
#         [ 4. ],
#         [ 4.1],
#         [ 4.5],
#         [ 4.9],
#         [ 5.1],
#         [ 5.3],
#         [ 5.9],
#         [ 6. ],
#         [ 6.8],
#         [ 7.1],
#         [ 7.9],
#         [ 8.2],
#         [ 8.7],
#         [ 9. ],
#         [ 9.5],
#         [ 9.6],
#         [10.3],
#         [10.5]]),
#  array([[  1.  ,   1.1 ,   1.21],
#         [  1.  ,   1.3 ,   1.69],
#         [  1.  ,   1.5 ,   2.25],
#         [  1.  ,   2.  ,   4.  ],
#         [  1.  ,   2.2 ,   4.84],
#         [  1.  ,   2.9 ,   8.41],
#         [  1.  ,   3.  ,   9.  ],
#         [  1.  ,   3.2 ,  10.24],
#         [  1.  ,   3.2 ,  10.24],
#         [  1.  ,   3.7 ,  13.69],
#         [  1.  ,   3.9 ,  15.21],
#         [  1.  ,   4.  ,  16.  ],
# ...

# %%
model2 = linear_model.LinearRegression()
model2.fit(X_poly , y)
# Out:
# LinearRegression()

# %%
ypredicted2 = model2.predict(X_poly)
ypredicted2
# Out:
# array([ 36419.97995933,  38279.7051688 ,  40140.74178358,  44799.07071874,
#         46664.69725209,  53204.7174356 ,  54140.31743855,  56012.50099842,
#         56012.50099842,  60698.69729633,  62575.47077478,  63514.34929099,
#         63514.34929099,  64453.55565853,  68213.65964195,  71979.00924659,
#         73863.65115687,  75749.60447246,  81415.33285105,  82360.76839379,
#         89936.05538347,  92782.19755149, 100386.33545789, 103243.29671968,
#        108011.45584918, 110876.2855428 , 115657.55872536, 116614.79691585,
#        123324.64408643, 125244.69393997])

# %%
plt.scatter(X  , y  , label = 'Actual_Values' ,c = 'b')
plt.scatter(X , ypredicted2 , label = 'Predicted_Values' , c = 'r')
plt.plot(X, ypredicted2 , label = 'Model')
plt.xlabel('Years_Of_Experince')
plt.ylabel('Salary_Per_Month')
plt.xticks(range(1,13,1))
plt.yticks(range(30000,135000,10000))
plt.title('Ploynomial_Regression_With_Degree_2')
plt.grid(True)

# %%
Score_PLR_2=model2.score(X_poly,y)
Score_PLR_2
# Out:
# 0.956975168321065

# %% [markdown]
# ### Ploynomial_Linear_Regression With Degree 3

# %%
pt = PolynomialFeatures(degree = 3)
X_poly = pt.fit_transform(X)
X , X_poly
model2 = linear_model.LinearRegression()
model2.fit(X_poly , y)
ypredicted2 = model2.predict(X_poly)
ypredicted2
plt.scatter(X  , y  , label = 'Actual_Values' ,c = 'b')
plt.scatter(X , ypredicted2 , label = 'Predicted_Values' , c = 'r')
plt.plot(X, ypredicted2 , label = 'Model')
plt.xlabel('Years_Of_Experince')
plt.ylabel('Salary_Per_Month')
plt.xticks(range(1,13,1))
plt.yticks(range(30000,135000,10000))
plt.title('Ploynomial_Regression_With_Degree_3')
plt.grid(True)
Score_PLR_3=model2.score(X_poly,y)
Score_PLR_3
# Out:
# 0.9635969766249464

# %% [markdown]
# ### Ploynomial_Linear_Regression With Degree 4

# %%
pt = PolynomialFeatures(degree = 4)
X_poly = pt.fit_transform(X)
X , X_poly
model2 = linear_model.LinearRegression()
model2.fit(X_poly , y)
ypredicted2 = model2.predict(X_poly)
ypredicted2
plt.scatter(X  , y  , label = 'Actual_Values' ,c = 'b')
plt.scatter(X , ypredicted2 , label = 'Predicted_Values' , c = 'r')
plt.plot(X, ypredicted2 , label = 'Model')
plt.xlabel('Years_Of_Experince')
plt.ylabel('Salary_Per_Month')
plt.xticks(range(1,13,1))
plt.yticks(range(30000,135000,10000))
plt.title('Ploynomial_Regression_With_Degree_4')
Score_PLR_4=model2.score(X_poly,y)
Score_PLR_4
# Out:
# 0.9636560599375091

# %% [markdown]
# ### Ploynomial_Linear_Regression With Degree 5¶

# %%
pt = PolynomialFeatures(degree = 5)
X_poly = pt.fit_transform(X)
X , X_poly
model2 = linear_model.LinearRegression()
model2.fit(X_poly , y)
ypredicted2 = model2.predict(X_poly)
ypredicted2
plt.scatter(X  , y  , label = 'Actual_Values' ,c = 'b')
plt.scatter(X , ypredicted2 , label = 'Predicted_Values' , c = 'r')
plt.plot(X, ypredicted2 , label = 'Model')
plt.xlabel('Years_Of_Experince')
plt.ylabel('Salary_Per_Month')
plt.xticks(range(1,13,1))
plt.yticks(range(30000,10000),)
plt.title('Ploynomial_Regression_With_Degree_5')
plt.grid(True)
Score_PLR_5=model2.score(X_poly,y)
Score_PLR_5
# Out:
# 0.9665546834956733

# %%
print(f'The Score of Polynomial Linear Regression is with Degree "3" is {Score_PLR_3}')
print(f'The Score of Polynomial Linear Regression is with Degree "4" is {Score_PLR_4}')
print(f'The Score of Polynomial Linear Regression is with Degree "5" is {Score_PLR_5}')
# Out:
# The Score of Polynomial Linear Regression is with Degree "3" is 0.9635969766249464
# The Score of Polynomial Linear Regression is with Degree "4" is 0.9636560599375091
# The Score of Polynomial Linear Regression is with Degree "5" is 0.9665546834956733

# %% [markdown]
# ##### The Prediction of the Polynomial Regression(Algorithm) with degree 5 for the same
# ##### Data_Set is Higher than from the rest.
